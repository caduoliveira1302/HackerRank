# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def birthdayCakeCandles(arr):
    tallest = max(arr)
    tallest_count = 0
    
    for value in arr:
        if value == tallest:
            tallest_count += 1
    return tallest_count

# %%
arr = [1,5,6,9,3,4,5,10,2,10,3,5,6,10]

birthdayCakeCandles(arr)
# Out:
# 3
