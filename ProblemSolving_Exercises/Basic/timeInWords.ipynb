# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
def timeInWords(h, m):
    assert 1 <= h <= 12 and 0 <= m <= 60

    num_dict = {1 : "one", 2 : "two", 3 : "three", 4 : "four", 5 : "five", 6 : "six", 7 : "seven", 8 : "eight",
            9 : "nine", 10 : "ten", 11 : "eleven", 12 : "twelve", 13 : "thirteen", 14 : "fourteen", 
            15 : "fiveteen", 16 : "sixteen", 17 : "seventenn", 18 : "eighteen", 19 : "nineteen", 20 : "twenty",
            21 : "twenty one", 22 : "twenty two", 23 : "twenty three", 24 : "twenty four", 25 : "twenty five", 
            26 : "twenty six", 27 : "twenty seven", 28 : "twenty eight", 29 : "twenty nine"}
    
    if m == 00:
        print(f"{num_dict[h]} o' clock")
    elif 1 <= m <= 30:
        if m == 15:
            print(f"quarter past {num_dict[h]}")
        elif m == 30:
            print(f"half past {num_dict[h]}")
        elif m == 1:
            print(f"{num_dict[m]} minute past {num_dict[h]}")
        else:
            print(f"{num_dict[m]} minutes past {num_dict[h]}")
    elif m > 30:
        next_hour = h + 1
        diff = 60 - m
        if diff == 15:
            print(f"quarter to {num_dict[next_hour]}")
        else:
            print(f"{num_dict[diff]} minutes to {num_dict[next_hour]}")

# %%
timeInWords(7, 15)
# Out:
# quarter past seven
