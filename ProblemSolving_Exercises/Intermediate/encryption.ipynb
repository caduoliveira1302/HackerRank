# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %%
import math

# %%
def encryption(s: str):
    #removing spaces
    s = s.replace(' ', '')

    #determining rows and columns
    sqrt = len(s) ** 0.5
    rows = math.floor(sqrt)
    columns = math.ceil(sqrt)
    
    #dividing the text in parts
    parts = [s[i:i+columns] for i in range(0, len(s), columns)]
    
    #max lenght of the parts
    max_len = max(len(part) for part in parts)
    
    #printing
    for i in range(max_len):
        for part in parts:
            if i < len(part): 
                print(part[i], end='')
        print(end=' ')

# %%
encryption('if man was meant to stay on the ground god would have given us roots')
# Out:
# imtgdvs fearwer mayoogo anouuio ntnnlvt wttddes aohghn sseoau

# %%
encryption('have a nice day')
# Out:
# hae and via ecy

# %%
encryption('feed the dog')
# Out:
# fto ehg ee dd

# %%
encryption('chill out')
# Out:
# clu hlt io
