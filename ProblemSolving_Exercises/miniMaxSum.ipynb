# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def miniMaxSum(arr):
    assert len(arr) == 5
    return print(sum(sorted(arr)[:4]), sum(sorted(arr)[-4:]))

# %%
arr = [3,6,2,9,1]

miniMaxSum(arr)
# Out:
# 12 20
