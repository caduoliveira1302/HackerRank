# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def staircase(n: int):
    for i in range(1, n+1, 1):
        if i < n:
            print(('#'*i).rjust(n))
        else:
            print('#'*i)

# %%
staircase(15)
# Out:
#               #
#              ##
#             ###
#            ####
#           #####
#          ######
#         #######
#        ########
#       #########
#      ##########
#     ###########
#    ############
#   #############
#  ##############
# ###############
